# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load dataset
df = pd.read_csv("parkinsons.csv")

# Drop 'name' column (not useful for predictions)
df = df.drop(columns=['name'])

# Drop least correlated (blue) features based on correlation matrix
drop_cols = ['MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'NHR', 'spread2', 'DFA']
df = df.drop(columns=drop_cols)

# Define features (X) and target label (Y)
X = df.drop(columns=['status'])
Y = df['status']

# Normalize feature values
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split into train and test sets (80-20 split)
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y, test_size=0.2, random_state=42)

# Build Neural Network Model
model = keras.Sequential([
    keras.layers.Dense(128, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001), input_shape=(X_train.shape[1],)),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(64, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(32, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dense(16, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dense(1, activation='sigmoid')  # Binary classification (0 = Healthy, 1 = Parkinson's)
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Implement Early Stopping
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the model
history = model.fit(X_train, Y_train, epochs=100, batch_size=16, validation_data=(X_test, Y_test), callbacks=[early_stopping])

# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, Y_test)
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# C:\Users\ANWESA\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.5696 - loss: 0.8565 - val_accuracy: 0.8718 - val_loss: 0.7895
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7587 - loss: 0.7629 - val_accuracy: 0.8462 - val_loss: 0.7098
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8493 - loss: 0.6765 - val_accuracy: 0.8462 - val_loss: 0.6289
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7682 - loss: 0.6188 - val_accuracy: 0.9231 - val_loss: 0.5607
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7871 - loss: 0.6011 - val_accuracy: 0.9231 - val_loss: 0.5185
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8144 - loss: 0.5414 - val_accuracy: 0.9231 - val_loss: 0.4950
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8173 - loss: 0.5198 - val_accuracy: 0.9231 - val_loss: 0.4805
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7982 - loss: 0.5359 - val_accuracy: 0.9231 - val_loss: 0.4759
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8328 - loss: 0.5227 - val_accuracy: 0.9231 - val_loss: 0.4730
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8415 - loss: 0.4979 - val_accuracy: 0.8974 - val_loss: 0.4730
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8879 - loss: 0.4298 - val_accuracy: 0.8718 - val_loss: 0.4915
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8231 - loss: 0.4698 - val_accuracy: 0.9231 - val_loss: 0.4655
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8161 - loss: 0.4726 - val_accuracy: 0.8974 - val_loss: 0.4697
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8619 - loss: 0.4131 - val_accuracy: 0.8974 - val_loss: 0.4640
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8853 - loss: 0.3890 - val_accuracy: 0.8974 - val_loss: 0.4703
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8521 - loss: 0.4398 - val_accuracy: 0.8974 - val_loss: 0.4490
# Epoch 17/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9011 - loss: 0.3835 - val_accuracy: 0.8974 - val_loss: 0.4519
# Epoch 18/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8716 - loss: 0.4327 - val_accuracy: 0.8974 - val_loss: 0.4572
# Epoch 19/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8784 - loss: 0.4065 - val_accuracy: 0.8974 - val_loss: 0.4408
# Epoch 20/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8605 - loss: 0.4313 - val_accuracy: 0.8974 - val_loss: 0.4377
# Epoch 21/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8712 - loss: 0.4560 - val_accuracy: 0.8974 - val_loss: 0.4464
# Epoch 22/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9116 - loss: 0.3689 - val_accuracy: 0.8974 - val_loss: 0.4364
# Epoch 23/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8423 - loss: 0.3895 - val_accuracy: 0.8974 - val_loss: 0.4355
# Epoch 24/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8954 - loss: 0.3296 - val_accuracy: 0.8974 - val_loss: 0.4242
# Epoch 25/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8417 - loss: 0.4292 - val_accuracy: 0.8974 - val_loss: 0.4315
# Epoch 26/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8905 - loss: 0.3750 - val_accuracy: 0.9231 - val_loss: 0.4328
# Epoch 27/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8645 - loss: 0.4092 - val_accuracy: 0.9231 - val_loss: 0.4355
# Epoch 28/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9211 - loss: 0.3268 - val_accuracy: 0.9231 - val_loss: 0.4479
# Epoch 29/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9109 - loss: 0.3240 - val_accuracy: 0.9231 - val_loss: 0.4224
# Epoch 30/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8994 - loss: 0.3726 - val_accuracy: 0.9231 - val_loss: 0.4169
# Epoch 31/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8465 - loss: 0.3851 - val_accuracy: 0.9231 - val_loss: 0.4277
# Epoch 32/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8982 - loss: 0.3533 - val_accuracy: 0.9231 - val_loss: 0.4257
# Epoch 33/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9054 - loss: 0.3358 - val_accuracy: 0.9231 - val_loss: 0.4126
# Epoch 34/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9188 - loss: 0.2965 - val_accuracy: 0.9231 - val_loss: 0.4179
# Epoch 35/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9024 - loss: 0.3193 - val_accuracy: 0.9231 - val_loss: 0.4130
# Epoch 36/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8901 - loss: 0.3370 - val_accuracy: 0.9231 - val_loss: 0.4047
# Epoch 37/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9002 - loss: 0.3282 - val_accuracy: 0.9231 - val_loss: 0.4113
# Epoch 38/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9245 - loss: 0.2932 - val_accuracy: 0.9231 - val_loss: 0.4035
# Epoch 39/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8847 - loss: 0.3320 - val_accuracy: 0.9231 - val_loss: 0.4026
# Epoch 40/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9073 - loss: 0.3142 - val_accuracy: 0.9231 - val_loss: 0.3959
# Epoch 41/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9147 - loss: 0.3002 - val_accuracy: 0.9231 - val_loss: 0.3993
# Epoch 42/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9201 - loss: 0.3039 - val_accuracy: 0.9231 - val_loss: 0.4096
# Epoch 43/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9148 - loss: 0.2839 - val_accuracy: 0.9231 - val_loss: 0.3981
# Epoch 44/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9134 - loss: 0.2760 - val_accuracy: 0.9231 - val_loss: 0.3992
# Epoch 45/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9204 - loss: 0.3071 - val_accuracy: 0.9231 - val_loss: 0.4004
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9383 - loss: 0.3713
# Test Accuracy: 0.9231

# %%
import pickle
# Save the model in H5 format
model.save("parkinsons_model.h5")

# Save the scaler and model in Pickle format
with open("parkinsons_scaler.pkl", "wb") as f:
    pickle.dump(scaler, f)
with open("parkinsons_model.pkl", "wb") as f:
    pickle.dump(model, f)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
